# %% [markdown]
# # Instagram Bot - 2

# %%
# Import all required Packages and Libraries
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from time import sleep
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import re

# %%
# Open the Chrome browser
# Note: My Webdriver is in the same folder as this Jupyter Notebook, If webdriver is installed in some different location use executable_path="PATH"
driver = webdriver.Chrome()

# %%
# Maximize the window 
driver.maximize_window()

# %%
# Initialize explicit wait for ensuring complete loading of webpages
wait = WebDriverWait(driver,10)

# %%
# Home page of Instagram
def goTOHomepage():
    driver.get('https://www.instagram.com/')

# %%
username = "SAMPLE_USERNAME"
password = "SAMPLE_PASSWORD"

# %% [markdown]
# Login to Instagram

# %%
goTOHomepage()

# %%
# Function to Login into Instagram Handle
def instaLogin(username,password):
    try:
        # Find Username and Password textbox, then enter username and password
        wait.until(EC.presence_of_element_located((By.NAME,'username'))).send_keys(username)
        wait.until(EC.presence_of_element_located((By.NAME,'password'))).send_keys(password)

        # Locating Login Button then submit it
        wait.until(EC.presence_of_element_located((By.TAG_NAME,'button'))).submit()
        sleep(1)

        # Locating and clicking "Not now" for saving login info
        wait.until(EC.presence_of_element_located((By.CLASS_NAME,'_ac8f'))).click()
        sleep(1)

        # Locating and clicking "Not Now" for Turn on Notification
        wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_a9-z"]/button[2]'))).click()

    except TimeoutException:
        print("Something Went Wrong!")

# Main Program
# Call instaLogin Function
instaLogin(username,password)

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Your friend has followed a lot of different food bloggers, he needs to analyse the habits of these bloggers.<br>

# %% [markdown]
# 1. From the list of instagram handles you obtained when you searched ‘food’ in previous project. Open the first 10 handles and find the top 5 which have the highest number of followers

# %% [markdown]
# Procedure to complete Task No 1 of Problem 1<br>
# 1. Search the 'food' string into search textbox and get the URLs of the Instagram handles appeared on search. Store them in a dictionary<br>
# 2. Go to each Instagram Handle and get their followers in a dictionary<br>
# 3. Find top 5 Instagram handles out of the follower count dictionary<br>
# 4. Show the top 5 instagram handle result on a pie chart

# %%
goTOHomepage()

# %%
# Function to search the given string and return the URLs of top n Insta Handles appeared as results
def search_and_store_handle_links(string,n):
    base_url = 'https://www.instagram.com/'
    user_urls = {}
    try:
        # Locate and Click on Search button
        wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR,"span.x1lliihq.x193iq5w.x6ikm8r.x10wlt62.xlyipyv.xuxw1ft")))[1].click()
        sleep(1)

        # Locating Search TextBox then enter search string
        wait.until(EC.presence_of_element_located((By.XPATH,"//input[@type='text']"))).send_keys(string)
        sleep(1)

        # Find all Search handle
        search_results = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR,'div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x6s0dn4.x1oa3qoh.x1nhvcw1')))
        sleep(1)
        
        # Iterate over search handle and extract the text
        for i in search_results[:n]:
            # print(i.text)
            user_urls[i.text] = base_url + i.text
            # print(user_urls[i.text])

        sleep(5)
        # Clearing search bar
        driver.find_element(By.CLASS_NAME,'_aawn._9-lv').click()

        return user_urls

    except TimeoutException:
        print("Something Went Wrong!")


# search_and_store_handle_links('food',10)
# Out:
# {'foodtalkindia': 'https://www.instagram.com/foodtalkindia',
#  'dilsefoodie': 'https://www.instagram.com/dilsefoodie',
#  'food_lunatic': 'https://www.instagram.com/food_lunatic',
#  'pune_food_blogger': 'https://www.instagram.com/pune_food_blogger',
#  'food_travel_etc': 'https://www.instagram.com/food_travel_etc',
#  'foodie_vakil': 'https://www.instagram.com/foodie_vakil',
#  'food': 'https://www.instagram.com/food',
#  'delhifoodie': 'https://www.instagram.com/delhifoodie',
#  'foodmapjaipur': 'https://www.instagram.com/foodmapjaipur',
#  'foodie_rushil': 'https://www.instagram.com/foodie_rushil'}

# %%
# Function to count the followers of given Instagram Handle
def getFollowerCount(insta_url):
    # Open the Instagram Handle
    driver.get(insta_url)
    sleep(2)

    # Locate the followers button
    data = wait.until(EC.presence_of_element_located((By.PARTIAL_LINK_TEXT,'followers')))
    # Store the followers button attributes and find the follower count number
    Follower_count = BeautifulSoup(data.get_attribute('outerHTML'),'html.parser').span['title']
    Follower_count=int(Follower_count.replace(',',''))

    return Follower_count
# getFollowerCount("https://www.instagram.com/foodtalkindia")
# Out:
# 309370

# %%
# Function to get the followers for all instagram Handles URL
def Count_Followers_of_all_Handles(users_URL):
    # Use a dictionary to store the follower counts of all handles
    Users_Followers = {}

    # Iterate for all insta handle urls
    for userName, url in users_URL.items():
        # Call getFollowerCount function
        followers = getFollowerCount(url)
        sleep(1)
        # Store the follower count corresponding to its username
        Users_Followers[userName] = followers
    
    return Users_Followers
# Count_Followers_of_all_Handles(
# {'foodtalkindia': 'https://www.instagram.com/foodtalkindia',
#  'food_lunatic': 'https://www.instagram.com/food_lunatic',
#  'food_and_makeup_lover': 'https://www.instagram.com/food_and_makeup_lover',
#  'food_travel_etc': 'https://www.instagram.com/food_travel_etc',
#  'foodiesince96': 'https://www.instagram.com/foodiesince96',
#  'dilsefoodie': 'https://www.instagram.com/dilsefoodie',
#  'food': 'https://www.instagram.com/food',
#  'foodbellydelites': 'https://www.instagram.com/foodbellydelites',
#  'foodisnirvana': 'https://www.instagram.com/foodisnirvana',
#  'foodelhi': 'https://www.instagram.com/foodelhi'})
# Out:
# {'foodtalkindia': 309370,
#  'food_lunatic': 222272,
#  'food_and_makeup_lover': 13527,
#  'food_travel_etc': 216787,
#  'foodiesince96': 330945,
#  'dilsefoodie': 1195154,
#  'food': 181635,
#  'foodbellydelites': 6944,
#  'foodisnirvana': 19758,
#  'foodelhi': 212704}

# %%
# Function to find top 5 Instagram handles by their follower count
def top5Handles(instaFollowers):

    # Create a list of keys sorted by their associated values in descending order
    sorted_handles = sorted(instaFollowers, key=instaFollowers.get, reverse=True)

    # Take the top 5 handles from the sorted list and create a new dictionary
    top5_dict = {userName: instaFollowers[userName] for userName in sorted_handles[:5]}

    return top5_dict

# instaFollowers = {'foodtalkindia': 309393, 'food_lunatic': 222115, 'foodisnirvana': 19761, 'food_travel_etc': 217798, 'food_and_makeup_lover': 13526, 'foodtalk_chennai': 118545, 'food': 181845, 'dilsefoodie': 1195045, 'foodiesince96': 330767, 'foodelhi': 212431}
# top5Handles(instaFollowers)
# Out:
# {'dilsefoodie': 1195045,
#  'foodiesince96': 330767,
#  'foodtalkindia': 309393,
#  'food_lunatic': 222115,
#  'food_travel_etc': 217798}

# %%
# Main Function to find the top 5 Instagram Handles based on followers count when searched for a string

# Find top 10 results on searching 'food' and store the Url of their Insta Handle
string = 'food' # Search for 'food'
n = 10          # get top 10 results

# Get top 10 insta handle urls
top10_insta_handle_urls = search_and_store_handle_links(string,n)

# Go to these handles and get the followers for top 10 results
insta_handles_followers = Count_Followers_of_all_Handles(top10_insta_handle_urls)

# Get top 5 insta handles 
top5_insta_handles = top5Handles(insta_handles_followers)
print(top5_insta_handles)
# Out:
# {'dilsefoodie': 1195154, 'foodtalkindia': 309370, 'food_lunatic': 222277, 'food_travel_etc': 216786, 'pune_food_blogger': 214604}

# %%
# Now display the results in a pie graph

# Store Follower count
count = list(top5_insta_handles.values())
# Store username of their insta handles
userId = list(top5_insta_handles.keys())


plt.figure(figsize=(10,10))
plt.pie(count,labels=userId,autopct="%.2f%%",counterclock=False,startangle=110)
plt.title('Top 5 user which have the highest number of followers ',fontsize=20, color='red',alpha=0.8)
plt.show()

# %% [markdown]
# 2. Now Find the number of posts these handles have done in the previous 3 days.

# %% [markdown]
# Procedure to complete Task No 2 of Problem 1<br>
# 1. Get the URL of top 5 Instagram handles<br>
# 2. Get the no of posts for top 5 instagram handles in last 3 days.<br>
# 3. results on a Bar Graph

# %%
# Function to get no of posts from a Insta Handle in the given no of days
def get_no_of_posts(user_url,No_of_Days):
    driver.get(user_url)
    sleep(2)
    
    # Open the First post
    wait.until(EC.presence_of_element_located((By.CSS_SELECTOR,'div._aabd._aa8k._al3l'))).click()
    # Counter for no of posts
    count = 0
    while True:
        # Get time of first post
        time_of_post = wait.until(EC.presence_of_element_located((By.XPATH,'//time[@class="_aaqe"]'))).get_attribute('datetime')
        # Convert time in no of days
        date_of_post = datetime.strptime(time_of_post[0:19], "%Y-%m-%dT%H:%M:%S")
        # Check if date of post is in the past 3 days or not by finding the difference of current date and date of post
        if (datetime.now() - date_of_post).days > No_of_Days :
            # If not within last 3 days break
            break
        else :
            # Within last 3 days then update the counter
            count += 1

        # Go to the next post by locating and clicking the next button
        Next_post = wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class=" _aaqg _aaqh"]/button')))
        Next_post.click()
        sleep(2)

    driver.back()
    return count

# %%
goTOHomepage()

# %%
# Function to get the urls of top 5 insta handles
def get_url_of_top_5_handles(top5_insta_handles):
    # Link of the base instagram URL
    base_url = 'https://www.instagram.com/'

    # Dictionary to store the url of corresponding instagram handle
    insta_urls = {}

    for username in top5_insta_handles:
        # Instagram handle url = Base Url + username of Instagram handle
        insta_urls[username] = base_url + username

    return insta_urls

# %%
# Main Program to find the no of posts in 3 days for top 5 insta handles

# Get url of top 5 insta handles
top_5_insta_urls = get_url_of_top_5_handles(top5_insta_handles)

# For counting the post in last n days
n = 3
no_of_posts = {}

for username in top_5_insta_urls:
    # Get Url of a single insta handle
    user_url = top_5_insta_urls[username]
    # Get no of posts by calling function n times for no of days
    post_Count = get_no_of_posts(user_url,n)
    # Store the result in no_of_post dictionary
    no_of_posts[username] = post_Count

# print no of post of top 5 insta handles in 3 days
no_of_posts
# Out:
# {'dilsefoodie': 0,
#  'foodtalkindia': 4,
#  'food_lunatic': 4,
#  'food_travel_etc': 0,
#  'pune_food_blogger': 4}

# %% [markdown]
# 3. Depict this information using a suitable graph.

# %%
# Get the Insta usernames on X axis
x_axis = no_of_posts.keys()
# Get the no of post in last 3 days of corresponding Insta handles on Y axis
y_axis = no_of_posts.values()

plt.bar(x_axis,y_axis,color='b',alpha=0.8)
plt.ylabel("No. of posts in the previous 3 days",size=12)
plt.xlabel("Instagram handles",size=12)
plt.xticks(rotation = 45)
plt.title('Most Followed user vs Number of recent posts ',fontsize=20, color='red',alpha=0.8)
plt.grid()
plt.show()

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Your friend also needs a list of hashtags that he should use in his posts.

# %% [markdown]
# 1. Open the 5 handles you obtained in the last question, and scrape the content of the first 10 posts of each handle.

# %% [markdown]
# Procedure to complete Task No 1 of Problem 2<br>
# 1. Create a funtion to scrape the word list from the desscription of Instagram handle for 10 posts<br>
# 2. Go to each Instagram Handle and get their word list and store it in a new list by iteration over the function<br>

# %%
goTOHomepage()

# %%
# Function to Scrape the content of a given Instagram handle from n no of posts
def content_of_post(user_url,No_of_post):
    # Word list to store the words
    word_list = []

    # Go to the Instagram handle page
    driver.get(user_url)
    sleep(5)

    # Locate and click on the first post
    wait.until(EC.presence_of_element_located((By.CSS_SELECTOR,'div._aabd._aa8k._al3l'))).click()
    sleep(1)

    # Counter to count the no of posts
    count = 1

    while True:
        # Check if post no is equal to counter or not 
        if No_of_post == count:
            break

        # Locate the div tag of the description of the post
        div = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'_a9zs')))

        # Get the description in a variable
        contents = BeautifulSoup(div.get_attribute('innerHTML'),'html.parser').text

        # Use re library to find the words and hashtags from contents variables
        results = re.findall(r'(#\w+|\b\w+\b)', contents)

        # Extenf the results in the word_list
        word_list.extend(results)

        # Increment the counter
        count += 1
    
        # Go to the next post by locating and clicking the next button
        wait.until(EC.presence_of_element_located((By.CSS_SELECTOR,"div._aaqg._aaqh"))).click()
        sleep(1)

    driver.back()
    return word_list
    
# content_of_post('https://www.instagram.com/foodtalkindia',10)
# Out:
# ['At',
#  'galaxypizza',
#  'in',
#  'they',
#  'serve',
#  'New',
#  'York',
#  'style',
#  'pizzas',
#  'that',
#  'are',
#  'simple',
#  'yet',
#  'extraordinary',
#  'Their',
#  'pizzas',
#  'are',
#  'all',
#  'about',
#  'using',
#  'fresh',
#  'and',
#  'high',
#  'quality',
#  'ingredients',
#  'The',
#  'crust',
#  'is',
#  'both',
#  'chewy',
#  'and',
#  'full',
#  'of',
#  'flavor',
#  'the',
#  'sauce',
#  'is',
#  'fresh',
#  'and',
#  'lively',
#  'and',
#  'the',
#  'toppings',
#  'are',
#  'generously',
#  'satisfying',
#  'What',
#  'makes',
#  'them',
#  'special',
#  'is',
#  'our',
#  'unique',
#  'New',
#  'York',
#  'Style',
#  'crust',
#  'This',
#  'is',
#  'for',
#  'people',
#  'who',
#  'like',
#  'crispier',
#  'chewier',
#  'crusts',
#  'and',
#  'breads',
#  'like',
#  'Sourdough',
#  'They',
#  'have',
#  'a',
#  'wide',
#  'range',
#  'of',
#  'gourmet',
#  'pizzas',
#  'that',
#  'are',
#  'delicious',
#  'unique',
#  'takes',
#  'on',
#  'both',
#  'classics',
#  'and',
#  'innovations',
#  'Order',
#  'now',
#  'from',
#  'their',
#  'outlets',
#  'in',
#  'Lajpat',
#  'or',
#  'Gurugram',
#  'Winter',
#  'festivities',
#  'are',
#  'knocking',
#  'with',
#  'Lohri',
#  'around',
#  'the',
#  'corner',
#  'From',
#  'scrumptious',
#  'treats',
#  'with',
#  'peanuts',
#  'gur',
#  'and',
#  'til',
#  'to',
#  'mouthwatering',
#  'savories',
#  'Lohri',
#  'vibes',
#  'are',
#  'in',
#  'the',
#  'air',
#  'Here',
#  's',
#  'a',
#  'list',
#  'of',
#  'places',
#  'to',
#  'order',
#  'your',
#  'Lohri',
#  'delights',
#  'from',
#  'Sip',
#  'into',
#  '200',
#  'years',
#  'of',
#  'tradition',
#  'with',
#  'beefeatergin',
#  'a',
#  'timeless',
#  'spirit',
#  'crafted',
#  'with',
#  'a',
#  'centuries',
#  'old',
#  'recipe',
#  'Immerse',
#  'yourself',
#  'in',
#  'the',
#  'versatility',
#  'of',
#  'this',
#  'perfectly',
#  'blended',
#  'gin',
#  'suitable',
#  'for',
#  'enthusiasts',
#  'and',
#  'first',
#  'time',
#  'sippers',
#  'alike',
#  'Uncover',
#  'the',
#  'British',
#  'history',
#  'behind',
#  'Beefeater',
#  'at',
#  'Gin',
#  'Explorers',
#  'Club',
#  '2024',
#  'on',
#  'the',
#  '20th',
#  'and',
#  '21st',
#  'of',
#  'January',
#  'Jio',
#  'World',
#  'Garden',
#  'Mumbai',
#  'Buy',
#  'your',
#  'early',
#  'bird',
#  'tickets',
#  'now',
#  'for',
#  'a',
#  'taste',
#  'of',
#  'British',
#  'heritage',
#  'Link',
#  'in',
#  'bio',
#  '#GinExplorersClub',
#  '#GinOClock',
#  'Discover',
#  'the',
#  'artistry',
#  'of',
#  'KI',
#  'NO',
#  'BI',
#  'Japanese',
#  'Gin',
#  'a',
#  'symphony',
#  'of',
#  'flavours',
#  'meticulously',
#  'distilled',
#  'and',
#  'blended',
#  'in',
#  'Kyoto',
#  'With',
#  'six',
#  'distinctive',
#  'elements',
#  'Base',
#  'Citrus',
#  'Tea',
#  'Herbal',
#  'Spice',
#  'and',
#  'Fruity',
#  'and',
#  'floral',
#  'it',
#  'captures',
#  'the',
#  'essence',
#  'of',
#  'Japanese',
#  'craftsmanship',
#  'Immerse',
#  'yourself',
#  'in',
#  'its',
#  'smooth',
#  'taste',
#  'at',
#  'the',
#  'Gin',
#  'Explorers',
#  'Club',
#  '2024',
#  'taking',
#  'place',
#  'at',
#  'Jio',
#  'Garden',
#  'in',
#  'Mumbai',
#  'on',
#  'January',
#  '20th',
#  'and',
#  '21st',
#  'Limited',
#  'early',
#  'bird',
#  'tickets',
#  'are',
#  'available',
#  'reserve',
#  'your',
#  'spot',
#  'now',
#  'Link',
#  'in',
#  'bio',
#  'A',
#  'ten',
#  'on',
#  'ten',
#  'experience',
#  'awaits',
#  'Tanqueray',
#  'No',
#  'TEN',
#  'presents',
#  'Tiny',
#  'TEN',
#  'Salon',
#  'Get',
#  'ready',
#  'for',
#  'an',
#  'exclusive',
#  'evening',
#  'of',
#  'magnificent',
#  'mixes',
#  'Witness',
#  'cocktail',
#  'artistry',
#  'by',
#  'Sago',
#  'House',
#  'as',
#  'they',
#  'take',
#  'over',
#  'Elephant',
#  'and',
#  'Co',
#  'Pune',
#  'and',
#  'Bandra',
#  'Born',
#  'Mumbai',
#  'MAKE',
#  'IT',
#  'A',
#  'TEN',
#  'Immerse',
#  'yourself',
#  'in',
#  'the',
#  'essence',
#  'of',
#  'the',
#  'Italian',
#  'Amalfi',
#  'Coast',
#  'with',
#  'malfygin',
#  'Come',
#  'live',
#  'La',
#  'Dolce',
#  'Vita',
#  'as',
#  'you',
#  'sip',
#  'on',
#  'the',
#  'beautiful',
#  'Malfy',
#  'Gin',
#  'Con',
#  'Limone',
#  'Experience',
#  'the',
#  'taste',
#  'of',
#  'Italian',
#  'summer',
#  'at',
#  'Gin',
#  'Explorers',
#  'Club',
#  'Retroverse',
#  'edition',
#  '2024',
#  'Mumbai',
#  'Secure',
#  'your',
#  'spot',
#  'and',
#  'dive',
#  'into',
#  'the',
#  'Italian',
#  'spirit',
#  'Tickets',
#  'link',
#  'in',
#  'bio',
#  'for',
#  'more',
#  'details',
#  '#GinOClock',
#  '#GinExplorersClub',
#  'Finding',
#  'top',
#  'notch',
#  'Chole',
#  'Bhature',
#  'in',
#  'the',
#  'capital',
#  'can',
#  'be',
#  'quite',
#  'the',
#  'quest',
#  'if',
#  'you',
#  're',
#  'unfamiliar',
#  'with',
#  'the',
#  'right',
#  'spots',
#  'Despite',
#  'the',
#  'city',
#  's',
#  'reputation',
#  'for',
#  'this',
#  'dish',
#  'pinpointing',
#  'the',
#  'ultimate',
#  'destination',
#  'can',
#  'be',
#  'tricky',
#  'Here',
#  's',
#  'a',
#  'list',
#  'of',
#  'some',
#  'great',
#  'spots',
#  'for',
#  'Chole',
#  'Bhature',
#  'Take',
#  'a',
#  'sip',
#  'of',
#  'history',
#  'with',
#  'monkey47',
#  'Gin',
#  'straight',
#  'from',
#  'the',
#  'heart',
#  'of',
#  'Germany',
#  's',
#  'Black',
#  'Forest',
#  'Immerse',
#  'yourself',
#  'in',
#  'the',
#  'story',
#  'at',
#  'the',
#  'Gin',
#  'Explorers',
#  'Club',
#  '2024',
#  'at',
#  'Jio',
#  'World',
#  'Garden',
#  'Mumbai',
#  'on',
#  'Jan',
#  '20th',
#  'and',
#  '21st',
#  '2024',
#  'Limited',
#  'early',
#  'bird',
#  'tickets',
#  'left',
#  'head',
#  'to',
#  'the',
#  'link',
#  'in',
#  'bio',
#  'and',
#  'buy',
#  'now',
#  '#GinExplorersClub',
#  '#GinOClock',
#  'Tanqueray',
#  'No',
#  'TEN',
#  'presents',
#  'Tiny',
#  'TEN',
#  'Salon',
#  'What',
#  'is',
#  'a',
#  'TEN',
#  'Some',
#  'of',
#  'the',
#  'finest',
#  'cocktails',
#  'made',
#  'with',
#  'one',
#  'of',
#  'the',
#  'finest',
#  'spirits',
#  'by',
#  'some',
#  'of',
#  'the',
#  'finest',
#  'mixologists',
#  'in',
#  'the',
#  'world',
#  'A',
#  'Night',
#  'of',
#  'cocktail',
#  'artistry',
#  'came',
#  'alive',
#  'at',
#  'the',
#  'Tiny',
#  'TEN',
#  'Salon',
#  'with',
#  'soulcompanyindia',
#  'as',
#  'Jesse',
#  'Vida',
#  'took',
#  'over',
#  'The',
#  'Quorum',
#  'Gurugram',
#  'and',
#  'Copitas',
#  'Bengaluru',
#  '#MakeItATEN',
#  '#TinyTENSalon']

# %%
# Extract the word list for top 5 insta handles

# Get url of top 5 insta handles
top_5_insta_urls = get_url_of_top_5_handles(top5_insta_handles)

# List to store the words of all all insta handles
words_of_5_users = []

# Iterate over the instagram url dictionary
for Id in top_5_insta_urls:
    # Get Url of the insta handle
    user_url = top_5_insta_urls[Id]

    # Call function to get word list for that insta handle
    text_list = content_of_post(user_url,10)

    # Extend the word list in words_of_5_users list
    words_of_5_users.extend(text_list)

    # Print the result for all insta handles
    print(Id,'->',text_list)
    print()
# Out:
# dilsefoodie -> ['#Ad', 'Garmi', 'ka', 'Mausam', 'aa', 'gaya', 'hai', 'toh', 'matlab', 'naya', 'ice', 'cream', 'flavour', 'toh', 'try', 'karna', 'chahiye', 'Tried', 'the', 'kwalitywalls', 'new', 'Hazelnut', 'Chocolate', 'Ice', 'cream', 'and', 'it', 'has', 'just', 'the', 'right', 'amount', 'of', 'sweetness', 'Go', 'check', 'it', 'out', 'Order', 'yours', 'on', 'Swiggy', 'or', 'get', 'it', 'from', 'your', 'nearest', 'Kwality', 'Wall', 's', 'freezer', '#CraftedForIndulgence', '#IceCream', '#Hazelnuts', '#Chocolate', '#hazelnutchocolate', '#dilsefoodie', '24', 'Haree', 'Mirch', 'And', '15', 'Nimbu', 'Daal', 'Ke', 'Banaye', 'Hai', 'Chacha', 'Bhatija', 'Special', 'Chole', 'Kulche', 'Thanks', 'To', 'agraeaters', 'For', 'Helping', 'Us', 'Exploring', 'Agra', 'Street', 'Food', '#dilsefoodie', '#food', '#streetfood', '#cholekulche', 'On', 'The', 'Occasion', 'Of', '75th', 'Independence', 'Day', 'ministryofculturegoi', 'Awarded', 'Us', 'As', 'One', 'Of', '75', 'Cultural', 'Brand', 'Ambassador', 'Of', 'India', 'At', 'amritmahotsav', 'We', 'Can', 't', 'Express', 'Our', 'Feelings', 'In', 'Words', 'But', 'We', 'Will', 'Promise', 'You', 'Guys', 'We', 'Will', 'Keep', 'Exploring', 'India', 'And', 'Will', 'Help', 'Local', 'Vendors', 'Government', 'Of', 'India', 'Is', 'Doing', 'A', 'Campaign', '#harghartiranga', 'So', 'I', 'Will', 'Hoist', 'Tiranga', 'At', 'My', 'Place', 'Tomorrow', 'And', 'You', 'Guys', 'Also', 'Participate', '#75For75', '#amritmohatsav', '#DilSeDesi', '#dilsefoodie', '3', 'Saal', 'Bartan', 'Dhone', 'Ke', 'Baad', 'Sikha', 'Kulche', 'Ka', 'Kaam', 'And', 'Then', 'Khud', 'ka', 'Kaam', 'Shuru', 'Kiya', '#dilsefoodie', '#food', '#amritsar', '#kulcha', '#kalashah', 'Rangeela', 'Egg', 'Corner', 'Ka', 'Special', 'LOLO', 'POPO', '#dilsefoodie', '#food', '#egg', '#corner', '#lolopopo', '#omelette', 'Old', 'Monk', 'Wala', 'Bater', 'At', 'bubby_fish_chicken_corner', 'Amritsar', '#dilsefoodie', '#food', '#bater', '#amritsar', '#foodfood', 'Try', 'Not', 'To', 'Laugh', 'Pavit', 'Tasting', 'Lemon', 'First', 'Time', '#dilsefoodie', '#food', '#lemon', '#baby', '#firstlemon', 'Can', 'You', 'Guess', 'The', 'Place', '#dilsefoodie', '#food', '#egg', '#omelette', '#ghaziabad', 'Badlu', 'Ke', 'Garma', 'Garam', 'Paranthe', 'In', 'Chandigarh', '#dilsefoodie', '#food', '#parantha', '#breakfast']
#
# foodtalkindia -> ['At', 'galaxypizza', 'in', 'they', 'serve', 'New', 'York', 'style', 'pizzas', 'that', 'are', 'simple', 'yet', 'extraordinary', 'Their', 'pizzas', 'are', 'all', 'about', 'using', 'fresh', 'and', 'high', 'quality', 'ingredients', 'The', 'crust', 'is', 'both', 'chewy', 'and', 'full', 'of', 'flavor', 'the', 'sauce', 'is', 'fresh', 'and', 'lively', 'and', 'the', 'toppings', 'are', 'generously', 'satisfying', 'What', 'makes', 'them', 'special', 'is', 'our', 'unique', 'New', 'York', 'Style', 'crust', 'This', 'is', 'for', 'people', 'who', 'like', 'crispier', 'chewier', 'crusts', 'and', 'breads', 'like', 'Sourdough', 'They', 'have', 'a', 'wide', 'range', 'of', 'gourmet', 'pizzas', 'that', 'are', 'delicious', 'unique', 'takes', 'on', 'both', 'classics', 'and', 'innovations', 'Order', 'now', 'from', 'their', 'outlets', 'in', 'Lajpat', 'or', 'Gurugram', 'Winter', 'festivities', 'are', 'knocking', 'with', 'Lohri', 'around', 'the', 'corner', 'From', 'scrumptious', 'treats', 'with', 'peanuts', 'gur', 'and', 'til', 'to', 'mouthwatering', 'savories', 'Lohri', 'vibes', 'are', 'in', 'the', 'air', 'Here', 's', 'a', 'list', 'of', 'places', 'to', 'order', 'your', 'Lohri', 'delights', 'from', 'Sip', 'into', '200', 'years', 'of', 'tradition', 'with', 'beefeatergin', 'a', 'timeless', 'spirit', 'crafted', 'with', 'a', 'centuries', 'old', 'recipe', 'Immerse', 'yourself', 'in', 'the', 'versatility', 'of', 'this', 'perfectly', 'blended', 'gin', 'suitable', 'for', 'enthusiasts', 'and', 'first', 'time', 'sippers', 'alike', 'Uncover', 'the', 'British', 'history', 'behind', 'Beefeater', 'at', 'Gin', 'Explorers', 'Club', '2024', 'on', 'the', '20th', 'and', '21st', 'of', 'January', 'Jio', 'World', 'Garden', 'Mumbai', 'Buy', 'your', 'early', 'bird', 'tickets', 'now', 'for', 'a', 'taste', 'of', 'British', 'heritage', 'Link', 'in', 'bio', '#GinExplorersClub', '#GinOClock', 'Discover', 'the', 'artistry', 'of', 'KI', 'NO', 'BI', 'Japanese', 'Gin', 'a', 'symphony', 'of', 'flavours', 'meticulously', 'distilled', 'and', 'blended', 'in', 'Kyoto', 'With', 'six', 'distinctive', 'elements', 'Base', 'Citrus', 'Tea', 'Herbal', 'Spice', 'and', 'Fruity', 'and', 'floral', 'it', 'captures', 'the', 'essence', 'of', 'Japanese', 'craftsmanship', 'Immerse', 'yourself', 'in', 'its', 'smooth', 'taste', 'at', 'the', 'Gin', 'Explorers', 'Club', '2024', 'taking', 'place', 'at', 'Jio', 'Garden', 'in', 'Mumbai', 'on', 'January', '20th', 'and', '21st', 'Limited', 'early', 'bird', 'tickets', 'are', 'available', 'reserve', 'your', 'spot', 'now', 'Link', 'in', 'bio', 'A', 'ten', 'on', 'ten', 'experience', 'awaits', 'Tanqueray', 'No', 'TEN', 'presents', 'Tiny', 'TEN', 'Salon', 'Get', 'ready', 'for', 'an', 'exclusive', 'evening', 'of', 'magnificent', 'mixes', 'Witness', 'cocktail', 'artistry', 'by', 'Sago', 'House', 'as', 'they', 'take', 'over', 'Elephant', 'and', 'Co', 'Pune', 'and', 'Bandra', 'Born', 'Mumbai', 'MAKE', 'IT', 'A', 'TEN', 'Immerse', 'yourself', 'in', 'the', 'essence', 'of', 'the', 'Italian', 'Amalfi', 'Coast', 'with', 'malfygin', 'Come', 'live', 'La', 'Dolce', 'Vita', 'as', 'you', 'sip', 'on', 'the', 'beautiful', 'Malfy', 'Gin', 'Con', 'Limone', 'Experience', 'the', 'taste', 'of', 'Italian', 'summer', 'at', 'Gin', 'Explorers', 'Club', 'Retroverse', 'edition', '2024', 'Mumbai', 'Secure', 'your', 'spot', 'and', 'dive', 'into', 'the', 'Italian', 'spirit', 'Tickets', 'link', 'in', 'bio', 'for', 'more', 'details', '#GinOClock', '#GinExplorersClub', 'Finding', 'top', 'notch', 'Chole', 'Bhature', 'in', 'the', 'capital', 'can', 'be', 'quite', 'the', 'quest', 'if', 'you', 're', 'unfamiliar', 'with', 'the', 'right', 'spots', 'Despite', 'the', 'city', 's', 'reputation', 'for', 'this', 'dish', 'pinpointing', 'the', 'ultimate', 'destination', 'can', 'be', 'tricky', 'Here', 's', 'a', 'list', 'of', 'some', 'great', 'spots', 'for', 'Chole', 'Bhature', 'Take', 'a', 'sip', 'of', 'history', 'with', 'monkey47', 'Gin', 'straight', 'from', 'the', 'heart', 'of', 'Germany', 's', 'Black ...
#
# food_lunatic -> ['Dilli', 'ki', 'sardi', 'definitely', 'calls', 'for', 'some', 'garam', 'tomato', 'soup', 'This', 'tomato', 'soup', 'is', 'so', 'easy', 'to', 'make', 'simply', 'roast', 'everything', 'blend', 'until', 'smooth', 'and', 'season', 'All', 'you', 'need', 'to', 'make', 'this', '1kg', 'tomatoes', '1', 'onion', '1', 'head', 'garlicDrizzle', 'with', 'olive', 'oil', 'season', 'with', 'salt', 'and', 'roast', 'at', '200', 'for', '50', 'mins', '1', '2', 'cup', 'water', 'A', 'handful', 'fresh', 'basil', 'leaves', '1', '4', 'cup', 'cream', 'Salt', 'and', 'black', 'pepper', 'to', 'taste', '#tomatosoup', '#roasted', '#winterrecipes', '#comfortfood', '#tasty', '#recipe', '#recipevideo', 'Why', 'go', 'for', 'khula', 'paneer', 'when', 'you', 'can', 'get', 'anandadairy', 'packed', 'paneer', 'at', 'your', 'nearest', 'store', 'which', 'is', '100', 'pure', 'I', 'did', 'a', 'small', 'research', 'and', 'realised', 'anandadairy', 'paneer', 'is', 'pure', 'natural', 'and', '100', 'safe', 'as', 'compared', 'to', 'khula', 'paneer', 'I', 'visited', 'their', 'manufacturing', 'unit', 'and', 'it', 'was', 'such', 'a', 'great', 'experience', 'I', 'was', 'honestly', 'really', 'impressed', 'with', 'the', 'staff', 'being', 'so', 'particular', 'about', 'hygiene', 'and', 'sanitation', 'Around', '50', '000', 'kgs', 'of', 'paneer', 'is', 'manufactured', 'daily', 'and', 'the', 'process', 'is', 'completely', 'automatic', 'and', 'untouched', 'by', 'hand', '#AnandaPaneer', '#PackedPaneer', '#UntouchedByHand', '#PurityCheck', '#Paneer', '#Ananda', '#AnandaDairy', 'Practiced', 'this', 'overnight', 'kaafi', 'kharab', 'coordination', 'but', 'I', 'still', 'think', 'we', 'did', 'a', 'pretty', 'good', 'job', 'Well', 'done', 'my', 'girls', 'komalarora95', 'prachiakapoor', 'resham826', '#weddingseason', '#danceperformance', '#love', '#cousins', '#softly', '#cousins', 'Sorry', 'insp_rahulsingh', 'I', 'dint', 'tell', 'you', 'before', 'but', 'I', 'was', 'a', 'part', 'of', 'this', 'plan', '#jootachurai', '#weddingseason', '#wedding', '#bridegroom', '#fun', '#funny', '#relatable', '#moyemoye', 'Saw', 'so', 'many', 'videos', 'of', 'this', 'bakery', 'but', 'it', 'was', 'a', 'complete', 'disappointment', 'Will', 'I', 'visit', 'this', 'bakery', 'again', 'No', 'Let', 'me', 'know', 'if', 'you', 'have', 'been', 'here', 'and', 'how', 'was', 'your', 'experience', '#bakery', '#preityzinta', '#trishoolbakers', '#shimla', '#viral', '#overhyped', '#minireview', 'First', 'trip', 'as', 'miya', 'biwi', 'I', 'know', 'it', 'looks', 'like', 'some', 'fancy', 'british', 'building', 'at', 'the', 'background', 'which', 'is', 'indeed', 'This', 'is', 'Indian', 'Institute', 'of', 'Advanced', 'Studies', 'in', 'Shimla', 'which', 'was', 'the', 'residence', 'of', 'Indian', 'Viceroy', 'back', 'in', '1880s', '#travel', '#traveldiaries', '#shimla', '#queenofhills', '#historic', '#himachal', '#iias', 'It', 'took', 'me', '3', 'months', 'to', 'decide', 'all', 'the', 'outfits', 'I', 'wore', 'on', 'the', 'functions', 'I', 'got', 'a', 'decent', 'saree', 'for', 'my', 'engagement', 'since', 'it', 'was', 'a', 'low', 'key', 'affair', 'my', 'mehendi', 'lehenga', 'was', 'customised', 'and', 'so', 'was', 'my', 'haldi', 'saree', 'because', 'I', 'wanted', 'the', 'exact', 'color', 'to', 'pair', 'it', 'with', 'pink', 'theme', 'and', 'my', 'wedding', 'lehenga', 'was', 'from', 'Chandni', 'Chowk', '#outfitsiwore', '#wedding', '#bride', '#weddingseason', '#ethnic', '#indianwedding', '#ootdshare', 'Rahul', 'and', 'I', 'know', 'each', 'other', 'since', '2010', 'Yes', 'it', 'was', 'me', 'who', 'initiated', 'this', 'friendship', 'which', 'eventually', 'turned', 'into', 'a', 'beautiful', 'relationship', 'I', 'always', 'knew', 'he', 'is', 'the', 'one', 'and', 'manifested', 'for', 'this', 'moment', 'It', 'still', 'feels', 'like', 'a', 'dream', '#bestfriends', '#bride', '#love', '#manifest', '#brideandgroom', '#dreamcometrue', '#weddingrituals', 'Trust', 'me', 'when', 'I', 'say', 'maggi', 'and', 'momos', 'at', 'hill', 'stations', 'a ...
#
# food_travel_etc -> ['Sunsets', 'and', 'palm', 'trees', 'life', 'in', 'the', 'Maldives', 'reethibeachresort', '#foodtraveletc', '#travel', '#maldives', '#reethibeachresort', '#luxurytravel', '#luxuryresort', '#collab', '#maldives', '#luxuryresort', '#maldivesislands', '#maldivesresorts', '#islandlife', '#island', 'Lost', 'in', 'the', 'allure', 'of', 'the', 'Maldives', 'at', 'reethibeachresort', 'our', 'haven', 'of', 'sun', 'kissed', 'days', 'surrounded', 'by', 'the', 'purest', 'blue', 'waters', '#foodtraveletc', '#maldives', '#reethibeachresort', '#baaatoll', '#maldivesislands', '#maldivesresorts', '#islandlife', '#maldivesinsider', '#luxury', '#collab', '#luxuryresort', 'Our', 'gateway', 'to', 'paradise', 'reethibeachresort', '#foodtraveletc', '#travel', '#maldives', '#collab', '#reethibeachresort', '#maldivesislands', '#maldivesresorts', '#maldivesisland', '#luxurytravel', '#islandvibes', '#island', '#luxury', '#watervilla', '#luxuryresort', 'Looking', 'back', 'at', 'the', 'fantastic', 'time', 'we', 'had', 'at', 'the', 'theleelapalacebengaluru', 'Being', 'the', 'only', 'modern', 'palace', 'in', 'Bengaluru', 'it', 'truly', 'exuded', 'palatial', 'charm', 'It', 'is', 'hard', 'to', 'pick', 'what', 'we', 'loved', 'more', 'the', 'elegant', 'turret', 'suite', '24', 'hour', 'butler', 'service', 'plethora', 'of', 'fine', 'dining', 'options', 'spa', 'or', 'the', 'overall', 'grand', 'architecture', 'We', 'recommend', 'using', 'ghadiscovery', 'to', 'book', 'your', 'stay', 'here', 'which', 'also', 'includes', 'exclusive', 'benefits', 'like', 'room', 'upgrades', 'and', 'late', 'check', 'out', 'among', 'others', 'How', 'cool', 'right', '#FoodTraveletc', '#GHADiscovery', '#RewardingLifesJourneys', '#TheLeelaPalaceBengaluru', '#LuxuryStay', '#TrueIndianLuxury', '#TheLeela', '#Luxury', '#LuxuryHotel', '#Collab', '#IndianLuxury', '#LuxuryTravel', '#LuxuryTraveller', 'Is', 'there', 'anything', 'more', 'satisfying', 'than', 'waking', 'up', 'to', 'a', 'breakfast', 'in', 'your', 'own', 'suite', 'shangrilablr', 'truly', 'spoiling', 'us', 'with', 'this', 'delightful', 'morning', 'indulgence', '#FoodTraveletc', '#ShangriLaBengaluru', '#FindYourShangriLa', '#MyShangriLa', '#ShangriLaCircle', '#Collab', '#Indulgence', '#BreakfastGoals', '#Breakfast', '#SuiteLife', '#Bengaluru', '#Luxury', '#LuxuryLifestyle', '#LuxuryLife', 'Welcoming', '2024', 'with', 'a', 'throwback', 'to', 'this', 'magical', 'dinner', 'setting', 'at', 'aurikacoorg', 'Would', 'you', 'like', 'to', 'experience', 'this', 'dinner', 'with', 'your', 'partner', '#foodtraveletc', '#travel', '#coorg', '#aurika', '#aurikacoorg', '#collab', '#luxury', '#luxurydining', '#romanticdinner', '#datenight', '#2024', '#happynewyear', '#aurikahotelsandresorts', '#luxurybylemontreehotels', '#beyondtheunusual', '#destinationsthatinspireajourney', 'Reflecting', 'on', 'a', 'year', 'of', 'breathtaking', 'destinations', 'unforgettable', 'moments', 'and', 'endless', 'adventures', 'From', 'sunrise', 'hikes', 'to', 'bustling', 'cities', '2023', 'was', 'a', 'whirlwind', 'of', 'exploration', 'and', 'discovery', 'Grateful', 'for', 'every', 'journey', 'shared', 'together', 'and', 'the', 'incredible', 'memories', 'made', 'Here', 's', 'to', 'another', 'year', 'of', 'wanderlust', 'and', 'new', 'horizons', '#FoodTraveletc', '#TravelDiaries', '#AdventuresOfUs', '#YearInReview', '#2023Recap', '#HappyNewYear', '#HappyNewYear2024', 'Our', 'headout', 'adventures', 'in', 'the', 'Big', 'Apple', 'From', 'dazzling', 'heights', 'and', 'iconic', 'sights', 'from', 'The', 'Edge', 'to', 'the', 'majestic', 'Lady', 'Liberty', 'our', 'adventures', 'in', 'New', 'York', 'City', 'were', 'a', 'series', 'of', 'unforgettable', 'moments', 'To', 'book', 'your', 'own', 'headout', 'adventure', 'use', 'our', 'code', 'FOODTRAVEL', 'to', 'get', '10', 'off', 'on', 'all', 'tours', '#foodtraveletc', '#travel', '#headout', '#letsheadout', '#HeadoutinNewYork', '#HeadoutinNYC', '#newyork', '#unitedstates', '#nyc', '#newyorkcity', '#newyorker', 'Soaking', 'i ...
#
# pune_food_blogger -> ['People', 'say', 'EAT', 'TO', 'LIVE', 'We', 'say', 'LIVE', 'TO', 'EAT', 'This', 'hidden', 'gem', 'is', 'a', 'haven', 'for', 'Maharashtra', 's', 'delectable', 'snacks', 'from', 'flavorful', 'Misal', 'and', 'Pohe', 'to', 'the', 'tempting', 'Tari', 'Pohe', 'sabudana', 'khichadi', 'and', 'the', 'iconic', 'vada', 'pav', 'each', 'bite', 'is', 'a', 'celebration', 'of', 'authentic', 'flavors', 'What', 's', 'more', 'delightful', 'The', 'pocket', 'friendly', 'prices', 'that', 'make', 'every', 'dish', 'a', 'steal', 'Our', 'experience', 'here', 'was', 'nothing', 'short', 'of', 'amazing', 'relishing', 'the', 'true', 'essence', 'of', 'Maharashtra', 'on', 'a', 'budget', 'Shot', 'on', 'Nikon', 'Z30', '#punefoodblogger', '#pune', '#poha', '#misal', '#sabudanakhichadi', '#vada', '#vadapav', '#pakode', 'People', 'say', 'EAT', 'TO', 'LIVE', 'We', 'say', 'LIVE', 'TO', 'EAT', 'Stepping', 'into', 'nostalgia', 'at', 'Great', 'Poona', 'Cold', 'Drink', 'House', 'Pune', 's', 'oldest', 'Falooda', 'haven', 'A', 'journey', 'through', 'time', 'with', 'delectable', 'desserts', 'and', 'the', 'star', 'of', 'the', 'menu', 'the', 'Cocktail', 'Falooda', 'A', 'delightful', 'blend', 'of', 'ice', 'cream', 'kulfi', 'rabdi', 'and', 'dry', 'fruits', 'it', 's', 'a', 'fan', 'favorite', 'among', 'Punekars', 'and', 'for', 'good', 'reason', 'The', 'desserts', 'here', 'are', 'not', 'just', 'great', 'but', 'come', 'at', 'a', 'nominal', 'price', 'offering', 'a', 'sweet', 'escape', 'that', 'feels', 'like', 'home', 'Shot', 'on', 'Nikon', 'Z30', '#punefoodblogger', '#pune', '#desserts', '#sweet', '#falooda', '#icecream', '#kulfi', 'People', 'say', 'EAT', 'TO', 'LIVEWe', 'say', 'LIVE', 'TO', 'EAT', 'We', 'often', 'find', 'heartwarming', 'stories', 'while', 'searching', 'for', 'awesome', 'eating', 'joints', 'While', 'on', 'Satara', 'Road', 'we', 'found', 'this', 'lovely', 'couple', 'selling', 'delicious', 'matki', 'chiwda', 'bhel', 'that', 'will', 'transport', 'you', 'to', 'your', 'childhood', 'days', 'They', 'have', 'been', 'together', 'for', '43', 'years', 'have', 'been', 'serving', 'this', 'comfort', 'snack', 'for', 'a', 'long', 'time', 'We', 'enjoyed', 'it', 'so', 'much', 'it', 's', 'only', 'for', 'Rs', '30', 'Made', 'with', 'fresh', 'ingredients', 'matki', 'chiwda', 'farsan', 'it', 's', 'a', 'quick', 'satisfying', 'snack', 'You', 'will', 'find', 'them', 'selling', 'it', 'from', 'their', 'two', 'wheeler', 'itself', 'We', 'love', 'to', 'support', 'local', 'vendors', 'you', 'should', 'too', 'Location', 'Walunj', 'Bandhu', 'Opposite', 'D', 'Mart', 'on', 'Satara', 'Road', 'Shot', 'on', 'Nikon', 'Z30', '#punefoodblogger', '#food', '#bhel', '#matki', '#bhelpuri', '#chaat', '#chaatlover', 'People', 'say', 'EAT', 'TO', 'LIVE', 'We', 'say', 'LIVE', 'TO', 'EAT', 'Embarking', 'on', 'a', 'flavorful', 'journey', 'at', 'Gatti', 'Chutney', 'the', 'only', 'spot', 'in', 'Pune', 'to', 'savor', 'the', 'authentic', 'taste', 'of', 'Bangalore', 'style', 'dosas', 'Our', 'top', 'pick', 'The', 'indulgent', 'Ghee', 'Garlic', 'Roast', 'Dosa', 'that', 'left', 'us', 'enchanted', 'Every', 'bite', 'is', 'a', 'plunge', 'into', 'rich', 'delicious', 'flavors', 'making', 'it', 'not', 'just', 'a', 'breakfast', 'but', 'a', 'cherished', 'experience', 'The', 'genuine', 'taste', 'of', 'Bangalore', 'found', 'its', 'way', 'to', 'Pune', 'making', 'Gatti', 'Chutney', 'a', 'favorite', 'morning', 'retreat', 'truly', 'a', 'delightful', 'blend', 'of', 'authenticity', 'value', 'for', 'money', 'and', 'irresistible', 'flavors', 'Address', 'Gatti', 'Chutney', 'Lane', '6', 'Koregaon', 'Park', '#punefoodblogger', '#pune', '#dosa', '#garlic', '#masaladosa', '#banglore', '#southindian', 'People', 'say', 'EAT', 'TO', 'LIVE', 'We', 'say', 'LIVE', 'TO', 'EAT', 'Indulging', 'in', 'the', 'South', 'Indian', 'symphony', 'at', 'Mankar', 'Dosa', 'Pune', 's', 'haven', 'for', 'dosa', 'lovers', 'From', 'the', 'crispy', 'Masala', 'Dosa', 'to', 'the', 'fluffy', 'Idlis', 'and', 'flavorful', 'Uthappas', 'the', 'menu', 'is', 'a ...

# %% [markdown]
# 2.Prepare a list of all words used in all the scraped posts and calculate the frequency of each word.

# %% [markdown]
# Procedure to complete Task No 2 of Problem 2<br>
# 1. Calculate the word frequency by using a dictionary and store it

# %%
# Function to calculate the freq of words 
def get_word_frequency(List_of_words):
    # Use dictionary to find and store frequency of words
    dct = {}
    for word in List_of_words:
        # Check if the word is present in dictionary...if not add one...if present then increase its frequency count
        dct[word] = dct.get(word,0) + 1
    return dct

word_freq_dict = get_word_frequency(words_of_5_users)
word_freq_dict
# Out:
# {'#Ad': 1,
#  'Garmi': 1,
#  'ka': 2,
#  'Mausam': 1,
#  'aa': 1,
#  'gaya': 1,
#  'hai': 1,
#  'toh': 2,
#  'matlab': 1,
#  'naya': 1,
#  'ice': 2,
#  'cream': 4,
#  'flavour': 1,
#  'try': 1,
#  'karna': 1,
#  'chahiye': 1,
#  'Tried': 1,
#  'the': 74,
#  'kwalitywalls': 1,
#  'new': 2,
#  'Hazelnut': 1,
#  'Chocolate': 1,
#  'Ice': 1,
#  'and': 62,
#  'it': 18,
#  'has': 1,
#  'just': 8,
#  'right': 3,
#  'amount': 1,
#  'of': 48,
#  'sweetness': 1,
#  'Go': 1,
#  'check': 2,
#  'out': 3,
#  'Order': 2,
#  'yours': 1,
#  'on': 18,
#  'Swiggy': 1,
#  'or': 4,
#  'get': 4,
#  'from': 10,
#  'your': 12,
#  'nearest': 2,
#  'Kwality': 1,
#  'Wall': 1,
#  's': 14,
#  'freezer': 1,
#  '#CraftedForIndulgence': 1,
#  '#IceCream': 1,
#  '#Hazelnuts': 1,
#  '#Chocolate': 1,
#  '#hazelnutchocolate': 1,
#  '#dilsefoodie': 9,
#  '24': 2,
#  'Haree': 1,
#  'Mirch': 1,
#  'And': 4,
#  '15': 1,
#  'Nimbu': 1,
#  'Daal': 1,
#  'Ke': 5,
#  'Banaye': 1,
#  'Hai': 1,
#  'Chacha': 1,
#  'Bhatija': 1,
#  'Special': 2,
#  'Chole': 4,
#  'Kulche': 2,
#  'Thanks': 1,
#  'To': 3,
#  'agraeaters': 1,
#  'For': 1,
#  'Helping': 1,
#  'Us': 2,
#  'Exploring': 2,
#  'Agra': 1,
#  'Street': 1,
#  'Food': 1,
#  '#food': 9,
#  '#streetfood': 2,
#  '#cholekulche': 1,
#  'On': 1,
#  'The': 12,
#  'Occasion': 1,
#  'Of': 4,
#  '75th': 1,
#  'Independence': 1,
#  'Day': 1,
#  'ministryofculturegoi': 1,
#  'Awarded': 1,
#  'As': 1,
#  'One': 1,
#  '75': 1,
#  'Cultural': 1,
#  'Brand': 1,
#  'Ambassador': 1,
#  'India': 3,
#  'At': 4,
#  'amritmahotsav': 1,
#  'We': 17,
#  'Can': 2,
#  't': 1,
#  'Express': 1,
#  'Our': 10,
#  'Feelings': 1,
#  'In': 2,
#  'Words': 1,
#  'But': 1,
#  'Will': 5,
#  'Promise': 1,
#  'You': 4,
#  'Guys': 2,
#  'Keep': 1,
#  'Help': 1,
#  'Local': 1,
#  'Vendors': 1,
#  'Government': 1,
#  'Is': 2,
#  'Doing': 1,
#  'A': 8,
#  'Campaign': 1,
#  '#harghartiranga': 1,
#  'So': 1,
#  'I': 16,
#  'Hoist': 1,
#  'Tiranga': 1,
#  'My': 1,
#  'Place': 2,
#  'Tomorrow': 1,
#  'Also': 1,
#  'Participate': 1,
#  '#75For75': 1,
#  '#amritmohatsav': 1,
#  '#DilSeDesi': 1,
#  '3': 2,
#  'Saal': 1,
#  'Bartan': 1,
#  'Dhone': 1,
#  'Baad': 1,
#  'Sikha': 1,
#  'Ka': 2,
#  'Kaam': 2,
#  'Then': 1,
#  'Khud': 1,
#  'Shuru': 1,
#  'Kiya': 1,
#  '#amritsar': 2,
#  '#kulcha': 1,
#  '#kalashah': 1,
#  'Rangeela': 1,
#  'Egg': 1,
#  'Corner': 1,
#  'LOLO': 1,
#  'POPO': 1,
#  '#egg': 2,
#  '#corner': 1,
#  '#lolopopo': 1,
#  '#omelette': 2,
#  'Old': 1,
#  'Monk': 1,
#  'Wala': 1,
#  'Bater': 1,
#  'bubby_fish_chicken_corner': 1,
#  'Amritsar': 1,
#  '#bater': 1,
#  '#foodfood': 1,
#  'Try': 1,
#  'Not': 1,
#  'Laugh': 1,
#  'Pavit': 1,
#  'Tasting': 1,
#  'Lemon': 1,
#  'First': 2,
#  'Time': 1,
#  '#lemon': 1,
#  '#baby': 1,
#  '#firstlemon': 1,
#  'Guess': 1,
#  '#ghaziabad': 1,
#  'Badlu': 1,
#  'Garma': 1,
#  'Garam': 1,
#  'Paranthe': 1,
#  'Chandigarh': 1,
#  '#parantha': 1,
#  '#breakfast': 1,
#  'galaxypizza': 1,
#  'in': 32,
#  'they': 2,
#  'serve': 1,
#  'New': 3,
#  'York': 3,
#  'style': 2,
#  'pizzas': 3,
#  'that': 11,
#  'are': 9,
#  'simple': 1,
#  'yet': 1,
#  'extraordinary': 1,
#  'Their': 1,
#  'all': 5,
#  'about': 4,
#  'using': 2,
#  'fresh': 4,
#  'high': 1,
#  'quality': 1,
#  'ingredients': 2,
#  'crust': 2,
#  'is': 20,
#  'both': 2,
#  'chewy': 1,
#  'full': 1,
#  'flavor': 2,
#  'sauce': 1,
#  'lively': 1,
#  'toppings': 1,
#  'generously': 1,
#  'satisfying': 3,
#  'What': 3,
#  'makes': 1,
#  'them': 2,
#  'special': 1,
#  'our': 4,
#  'unique': 2,
#  'Style': 1,
#  'This': 4,
#  'for': 26,
#  'people': 1,
#  'who': 2,
#  'like': 11,
#  'crispier': 1,
#  'chewier': 1,
#  'crusts': 1,
#  'breads': 1,
#  'Sourdough': 1,
#  'They': 2,
#  'have': 4,
#  'a': 54,
#  'wide': 1,
#  'range': 1,
#  'gourmet': 1,
#  'delicious': 4,
#  'takes': 1,
#  'classics': 1,
#  'innovations': 1,
#  'now': 4,
#  'their': 5,
#  'outlets': 1,
#  'Lajpat': 1,
#  'Gurugram': 2,
#  'Winter': 1,
#  'festivities': 1,
#  'knocking': 1,
#  'with': 23,
#  'Lohri': 3,
#  'around': 1,
#  'corner': 1,
#  'From': 5,
#  'scrumptious': 1,
#  'treats': 1,
#  'peanuts': 1,
#  'gur': 1,
#  'til': 1,
#  'to': 33,
#  'mouthwatering': 1,
#  'savories': 1,
#  'vibes': 1,
#  'air': 1,
#  'Here': 3,
#  'list': 2,
#  'places': 2,
#  'order': 1,
#  'delights': 1,
#  'Sip': 1,
#  'into': 5,
#  '200': 2,
#  'years': 2,
#  'tradition': 1,
#  'beefeatergin': 1,
#  'timeless': 1,
#  'spirit': 2,
#  'crafted': 2,
#  'centuries': 1,
#  'old': 1,
#  'recipe': 1,
#  'Immerse': 4,
#  'yourself': 4,
#  'versatility': 1,
#  'this': 15,
#  'perfectly': 1,
#  'blended': 2,
#  'gin': 1,
#  'suitable': 1,
#  'enthusiasts': 1,
#  'first': 1,
#  'time': 5,
#  'sippers': 1,
#  'alike': 1,
#  'Uncover': 1,
#  'British': 2,
#  'history': 2,
#  'behind': 1,
#  'Beefeater': 1,
#  'at': 23,
#  'Gin': 7,
#  'Explorers': 4,
#  'Club': 4,
#  '2024': 6,
#  '20th': 3,
#  '21st': 3,
#  'January': 2,
#  'Jio': 3,
#  'World': 2,
#  'Garden': 3,
#  'Mumbai': 5,
#  'Buy': 1,
#  'early': 3,
#  'bird': 3,
#  'tickets': 3,
#  'taste': 9,
#  'heritage': 1,
#  'Link': 2,
#  'bio': 4,
#  '#GinExplorersClub': 3,
#  '#GinOClock': 3,
#  'Discover': 1,
#  'artistry': 3,
#  'KI': 1,
#  'NO': 1,
#  'BI': 1,
#  'Japanese': 2,
#  'symphony': 3,
#  'flavours': 1,
#  'meticulously': 1,
#  'distilled': 1,
#  'Kyoto': 1,
#  'With': 1,
#  'six': 1,
#  'distinctive': 1,
#  'elements': 1,
#  'Base': 1,
#  'Citrus': 1,
#  'Tea': 1,
#  'Herbal': 1,
#  'Spice': 1,
#  'Fruity': 1,
#  'floral': 1,
#  'captures': 1,
#  'essence': 3,
#  'craftsmanship': 1,
#  'its': 2,
#  'smooth': 2,
#  'taking': 1,
#  'place': 3,
#  'Limited': 2,
#  'available': 1,
#  'reserve': 1,
#  'spot': 3,
#  'ten': 2,
#  'experience': 11,
#  'awaits': 1,
#  'Tanqueray': 2,
#  'No': 4,
#  'TEN': 7,
#  'presents': 2,
#  'Tiny': 3,
#  'Salon': 3,
#  'Get': 1,
#  'ready': 1,
#  'an': 5,
#  'exclusive': 2,
#  'evening': 1,
#  'magnificent': 1,
#  'mixes': 1,
#  'Witness': 1,
#  'cocktail': 2,
#  'by': 4,
#  'Sago': 1,
#  'House': 2,
#  'as': 5,
#  'take': 1,
#  'over': 2,
#  'Elephant': 1,
#  'Co': 1,
#  'Pune': 6,
#  'Bandra': 1,
#  'Born': 1,
#  'MAKE': 1,
#  'IT': 2,
#  'Italian': 3,
#  'Amalfi': 1,
#  'Coast': 1,
#  'malfygin': 1,
#  'Come': 1,
#  'live': 1,
#  'La': 1,
#  'Dolce': 1,
#  'Vita': 1,
#  'you': 10,
#  'sip': 2,
#  'beautiful': 2,
#  'Malfy': 1,
#  'Con': 1,
#  'Limone': 1,
#  'Experience': 1,
#  'summer': 1,
#  'Retroverse': 1,
#  'edition': 1,
#  'Secure': 1,
#  'dive': 1,
#  'Tickets': 1,
#  'link': 2,
#  'more': 6,
#  'details': 1,
#  'Finding': 1,
#  'top': 2,
#  'notch': 1,
#  'Bhature': 5,
#  'capital': 1,
#  'can': 4,
#  'be': 3,
#  'quite': 1,
#  'quest': 1,
#  'if': 2,
#  're': 2,
#  'unfamiliar': 1,
#  'spots': 2,
#  'Despite': 1,
#  'city': 1,
#  'reputation': 1,
#  'dish': 3,
#  'pinpointing': 1,
#  'ultimate': 1,
#  'destination': 1,
#  'tricky': 1,
#  'some': 5,
#  'great': 3,
#  'Take': 1,
#  'monkey47': 1,
#  'straight': 1,
#  'heart': 1,
#  'Germany': 1,
#  'Black': 1,
#  'Forest': 1,
#  'story': 1,
#  'Jan': 1,
#  'left': 4,
#  'head': 2,
#  'buy': 1,
#  'Some': 1,
#  'finest': 3,
#  'cocktails': 1,
#  'made': 2,
#  'one': 3,
#  'spirits': 1,
#  'mixologists': 1,
#  'world': 1,
#  'Night': 1,
#  'came': 1,
#  'alive': 1,
#  'soulcompanyindia': 1,
#  'Jesse': 1,
#  'Vida': 1,
#  'took': 2,
#  'Quorum': 1,
#  'Copitas': 1,
#  'Bengaluru': 2,
#  '#MakeItATEN': 1,
#  '#TinyTENSalon': 1,
#  'Dilli': 1,
#  'ki': 1,
#  'sardi': 1,
#  'definitely': 1,
#  'calls': 1,
#  'garam': 1,
#  'tomato': 2,
#  'soup': 2,
#  'so': 6,
#  'easy': 1,
#  'make': 3,
#  'simply': 1,
#  'roast': 2,
#  'everything': 2,
#  'blend': 3,
#  'until': 1,
#  'season': 2,
#  'All': 1,
#  'need': 1,
#  '1kg': 1,
#  'tomatoes': 1,
#  '1': 4,
#  'onion': 1,
#  'garlicDrizzle': 1,
#  'olive': 1,
#  'oil': 1,
#  'salt': 1,
#  '50': 2,
#  'mins': 1,
#  '2': 1,
#  'cup': 2,
#  'water': 1,
#  'handful': 1,
#  'basil': 1,
#  'leaves': 1,
#  '4': 2,
#  'Salt': 1,
#  'black': 1,
#  'pepper': 1,
#  '#tomatosoup': 1,
#  '#roasted': 1,
#  '#winterrecipes': 1,
#  '#comfortfood': 1,
#  '#tasty': 2,
#  '#recipe': 1,
#  '#recipevideo': 1,
#  'Why': 1,
#  'go': 1,
#  'khula': 2,
#  'paneer': 5,
#  'when': 2,
#  'anandadairy': 2,
#  'packed': 1,
#  'store': 1,
#  'which': 5,
#  '100': 2,
#  'pure': 2,
#  'did': 2,
#  'small': 1,
#  'research': 1,
#  'realised': 1,
#  'natural': 1,
#  'safe': 1,
#  'compared': 1,
#  'visited': 2,
#  'manufacturing': 1,
#  'unit': 1,
#  'was': 15,
#  'such': 1,
#  'honestly': 1,
#  'really': 2,
#  'impressed': 1,
#  'staff': 1,
#  'being': 2,
#  'particular': 1,
#  'hygiene': 1,
#  'sanitation': 1,
#  'Around': 1,
#  '000': 1,
#  'kgs': 1,
#  'manufactured': 1,
#  'daily': 1,
#  'process': 1,
#  'completely': 1,
#  'automatic': 1,
#  'untouched': 1,
#  'hand': 1,
#  '#AnandaPaneer': 1,
#  '#PackedPaneer': 1,
#  '#UntouchedByHand': 1,
#  '#PurityCheck': 1,
#  '#Paneer': 1,
#  '#Ananda': 1,
#  '#AnandaDairy': 1,
#  'Practiced': 1,
#  'overnight': 1,
#  'kaafi': 1,
#  'kharab': 1,
#  'coordination': 1,
#  'but': 10,
#  'still': 2,
#  'think': 1,
#  'we': 6,
#  'pretty': 1,
#  'good': 4,
#  'job': 1,
#  'Well': 1,
#  'done': 1,
#  'my': 5,
#  'girls': 1,
#  'komalarora95': 1,
#  'prachiakapoor': 1,
#  'resham826': 1,
#  '#weddingseason': 3,
#  '#danceperformance': 1,
#  '#love': 2,
#  '#cousins': 2,
#  '#softly': 1,
#  'Sorry': 1,
#  'insp_rahulsingh': 1,
#  'dint': 1,
#  'tell': 1,
#  'before': 1,
#  'part': 1,
#  'plan': 1,
#  '#jootachurai': 1,
#  '#wedding': 2,
#  '#bridegroom': 1,
#  '#fun': 1,
#  '#funny': 1,
#  '#relatable': 1,
#  '#moyemoye': 1,
#  'Saw': 1,
#  'many': 2,
#  'videos': 1,
#  'bakery': 2,
#  'complete': 1,
#  'disappointment': 1,
#  'visit': 2,
#  'again': 1,
#  'Let': 1,
#  'me': 4,
#  'know': 3,
#  'been': 3,
#  'here': 5,
#  'how': 1,
#  '#bakery': 1,
#  '#preityzinta': 1,
#  '#trishoolbakers': 1,
#  '#shimla': 3,
#  '#viral': 1,
#  '#overhyped': 1,
#  '#minireview': 1,
#  'trip': 1,
#  'miya': 1,
#  'biwi': 1,
#  'looks': 1,
#  'fancy': 1,
#  'british': 1,
#  'building': 1,
#  'background': 1,
#  'indeed': 1,
#  'Indian': 4,
#  'Institute': 1,
#  'Advanced': 1,
#  'Studies': 1,
#  'Shimla': 1,
#  'residence': 1,
#  'Viceroy': 1,
#  'back': 2,
#  '1880s': 1,
#  '#travel': 6,
#  '#traveldiaries': 1,
#  '#queenofhills': 1,
#  '#historic': 1,
#  '#himachal': 1,
#  '#iias': 1,
#  'It': 3,
#  'months': 1,
#  'decide': 1,
#  'outfits': 1,
#  'wore': 1,
#  'functions': 1,
#  'got': 1,
#  'decent': 1,
#  'saree': 2,
#  'engagement': 1,
#  'since': 2,
#  'low': 1,
#  'key': 1,
#  'affair': 1,
#  'mehendi': 1,
#  'lehenga': 2,
#  'customised': 1,
#  'haldi': 1,
#  'because': 1,
#  'wanted': 1,
#  'exact': 1,
#  'color': 1,
#  'pair': 1,
#  'pink': 1,
#  'theme': 1,
#  'wedding': 1,
#  'Chandni': 1,
#  'Chowk': 1,
#  '#outfitsiwore': 1,
#  '#bride': 2,
#  '#ethnic': 1,
#  '#indianwedding': 1,
#  '#ootdshare': 1,
#  'Rahul': 1,
#  'each': 2,
#  'other': 1,
#  '2010': 1,
#  'Yes': 2,
#  'initiated': 1,
#  'friendship': 1,
#  'eventually': 1,
#  'turned': 1,
#  'relationship': 1,
#  'always': 1,
#  'knew': 1,
#  'he': 1,
#  'manifested': 1,
#  'moment': 1,
#  'feels': 2,
#  'dream': 1,
#  '#bestfriends': 1,
#  '#manifest': 1,
#  '#brideandgroom': 1,
#  '#dreamcometrue': 1,
#  '#weddingrituals': 1,
#  'Trust': 1,
#  'say': 19,
#  'maggi': 1,
#  'momos': 1,
#  'hill': 1,
#  'stations': 1,
#  'overrated': 1,
#  'literally': 1,
#  'had': 2,
#  '5': 1,
#  'these': 1,
#  'pocket': 3,
#  'kulchas': 1,
#  'alone': 1,
#  '#pocketkulcha': 1,
#  '#explore': 1,
#  '#explorepage': 1,
#  'Sunsets': 1,
#  'palm': 1,
#  'trees': 1,
#  'life': 1,
#  'Maldives': 2,
#  'reethibeachresort': 3,
#  '#foodtraveletc': 5,
#  '#maldives': 4,
#  '#reethibeachresort': 3,
#  '#luxurytravel': 2,
#  '#luxuryresort': 4,
#  '#collab': 4,
#  '#maldivesislands': 3,
#  '#maldivesresorts': 3,
#  '#islandlife': 2,
#  '#island': 2,
#  'Lost': 1,
#  'allure': 1,
#  'haven': 5,
#  'sun': 1,
#  'kissed': 1,
#  'days': 2,
#  'surrounded': 1,
#  'purest': 1,
#  'blue': 1,
#  'waters': 1,
#  '#baaatoll': 1,
#  '#maldivesinsider': 1,
#  '#luxury': 3,
#  'gateway': 1,
#  'paradise': 1,
#  '#maldivesisland': 1,
#  '#islandvibes': 1,
#  '#watervilla': 1,
#  'Looking': 1,
#  'fantastic': 1,
#  'theleelapalacebengaluru': 2,
#  'Being': 1,
#  'only': 3,
#  'modern': 1,
#  'palace': 1,
#  'truly': 3,
#  'exuded': 1,
#  'palatial': 1,
#  'charm': 1,
#  'hard': 1,
#  'pick': 2,
#  'what': 1,
#  'loved': 1,
#  'elegant': 1,
#  'turret': 1,
#  'suite': 2,
#  'hour': 1,
#  'butler': 1,
#  'service': 1,
#  'plethora': 1,
#  'fine': 1,
#  'dining': 1,
#  'options': 3,
#  'spa': 1,
#  'overall': 1,
#  'grand': 1,
#  'architecture': 1,
#  'recommend': 1,
#  'ghadiscovery': 2,
#  'book': 2,
#  'stay': 1,
#  'also': 2,
#  'includes': 1,
#  'benefits': 1,
#  'room': 1,
#  'upgrades': 1,
#  'late': 1,
#  'among': 2,
#  'others': 2,
#  'How': 1,
#  'cool': 1,
#  '#FoodTraveletc': 4,
#  '#GHADiscovery': 2,
#  '#RewardingLifesJourneys': 2,
#  '#TheLeelaPalaceBengaluru': 2,
#  '#LuxuryStay': 1,
#  '#TrueIndianLuxury': 1,
#  '#TheLeela': 1,
#  '#Luxury': 3,
#  '#LuxuryHotel': 1,
#  '#Collab': 3,
#  '#IndianLuxury': 1,
#  '#LuxuryTravel': 2,
#  '#LuxuryTraveller': 1,
#  'there': 1,
#  'anything': 1,
#  'than': 1,
#  'waking': 1,
#  'up': 1,
#  'breakfast': 3,
#  'own': 2,
#  'shangrilablr': 1,
#  'spoiling': 1,
#  'us': 4,
#  'delightful': 8,
#  'morning': 2,
#  'indulgence': 1,
#  '#ShangriLaBengaluru': 1,
#  '#FindYourShangriLa': 1,
#  '#MyShangriLa': 1,
#  '#ShangriLaCircle': 1,
#  '#Indulgence': 1,
#  '#BreakfastGoals': 1,
#  '#Breakfast': 1,
#  '#SuiteLife': 1,
#  '#Bengaluru': 1,
#  '#LuxuryLifestyle': 1,
#  '#LuxuryLife': 1,
#  'Welcoming': 1,
#  'throwback': 1,
#  'magical': 1,
#  'dinner': 2,
#  'setting': 1,
#  'aurikacoorg': 1,
#  'Would': 1,
#  'partner': 1,
#  '#coorg': 1,
#  '#aurika': 1,
#  '#aurikacoorg': 1,
#  '#luxurydining': 1,
#  '#romanticdinner': 1,
#  '#datenight': 1,
#  '#2024': 1,
#  '#happynewyear': 1,
#  '#aurikahotelsandresorts': 1,
#  '#luxurybylemontreehotels': 1,
#  '#beyondtheunusual': 1,
#  '#destinationsthatinspireajourney': 1,
#  'Reflecting': 1,
#  'year': 2,
#  'breathtaking': 2,
#  'destinations': 1,
#  'unforgettable': 2,
#  'moments': 2,
#  'endless': 1,
#  'adventures': 3,
#  'sunrise': 1,
#  'hikes': 1,
#  'bustling': 1,
#  'cities': 1,
#  '2023': 1,
#  'whirlwind': 1,
#  'exploration': 1,
#  'discovery': 2,
#  'Grateful': 1,
#  'every': 3,
#  'journey': 4,
#  'shared': 1,
#  'together': 2,
#  'incredible': 1,
#  'memories': 1,
#  'another': 1,
#  'wanderlust': 1,
#  'horizons': 1,
#  '#TravelDiaries': 1,
#  '#AdventuresOfUs': 1,
#  '#YearInReview': 1,
#  '#2023Recap': 1,
#  '#HappyNewYear': 1,
#  '#HappyNewYear2024': 1,
#  'headout': 2,
#  'Big': 1,
#  'Apple': 1,
#  'dazzling': 1,
#  'heights': 1,
#  'iconic': 2,
#  'sights': 1,
#  'Edge': 1,
#  'majestic': 1,
#  'Lady': 1,
#  'Liberty': 1,
#  'City': 1,
#  'were': 2,
#  'series': 1,
#  'adventure': 1,
#  'use': 1,
#  'code': 1,
#  'FOODTRAVEL': 1,
#  '10': 1,
#  'off': 1,
#  'tours': 1,
#  '#headout': 1,
#  '#letsheadout': 1,
#  '#HeadoutinNewYork': 1,
#  '#HeadoutinNYC': 1,
#  '#newyork': 1,
#  '#unitedstates': 1,
#  '#nyc': 1,
#  '#newyorkcity': 1,
#  '#newyorker': 1,
#  'Soaking': 1,
#  'festive': 1,
#  'magic': 1,
#  'Courtesy': 1,
#  '#Christmas': 1,
#  '#HolidaySeason': 1,
#  'People': 9,
#  'EAT': 18,
#  'TO': 18,
#  'LIVE': 17,
#  'hidden': 1,
#  'gem': 2,
#  'Maharashtra': 2,
#  'delectable': 3,
#  'snacks': 1,
#  'flavorful': 3,
#  'Misal': 3,
#  'Pohe': 3,
#  'tempting': 1,
#  'Tari': 1,
#  'sabudana': 1,
#  'khichadi': 1,
#  'vada': 1,
#  'pav': 1,
#  'bite': 2,
#  'celebration': 2,
#  'authentic': 4,
#  'flavors': 8,
#  'friendly': 2,
#  'prices': 1,
#  'steal': 1,
#  'nothing': 1,
#  'short': 1,
#  'amazing': 1,
#  'relishing': 1,
#  'true': 1,
#  'budget': 1,
#  'Shot': 4,
#  'Nikon': 4,
#  'Z30': 4,
#  '#punefoodblogger': 9,
#  '#pune': 8,
#  '#poha': 1,
#  '#misal': 2,
#  '#sabudanakhichadi': 1,
#  '#vada': 1,
#  '#vadapav': 1,
#  '#pakode': 1,
#  'Stepping': 1,
#  'nostalgia': 1,
#  'Great': 1,
#  'Poona': 1,
#  'Cold': 1,
#  'Drink': 1,
#  'oldest': 1,
#  'Falooda': 2,
#  'through': 2,
#  'desserts': 2,
#  'star': 1,
#  'menu': 4,
#  'Cocktail': 1,
#  'kulfi': 1,
#  'rabdi': 1,
#  'dry': 1,
#  'fruits': 1,
#  'fan': 1,
#  'favorite': 3,
#  'Punekars': 1,
#  'reason': 1,
#  'not': 6,
#  'come': 1,
#  'nominal': 1,
#  'price': 1,
#  'offering': 1,
#  'sweet': 1,
#  'escape': 1,
#  'home': 1,
#  '#desserts': 1,
#  '#sweet': 1,
#  '#falooda': 1,
#  '#icecream': 2,
#  '#kulfi': 1,
#  'LIVEWe': 1,
#  'often': 1,
#  'find': 2,
#  'heartwarming': 1,
#  ...}

# %% [markdown]
# 3. Create a csv file with two columns : the word and its frequency

# %% [markdown]
# Procedure to complete Task No 3 of Problem 2<br>
# 1. Get the frequency dictionary from task 2 and use it create a data frame<br>
# 2. Use columns - Words and Frequency for storing the data <br>
# 3. Convert data frame into csv file

# %%
# Store the words in a list
words = [ key for key,value in word_freq_dict.items()]

# Store their freq in another list
word_frequency = [ value for key,value in word_freq_dict.items()]

# columns : the word and its frequency
columns = {"Word":words,"Frequency":word_frequency}

# Create the pandas dataframe for this column using words and frq list
df = pd.DataFrame(columns)
print(df.head(10))
# using .to_csv pandas function to convert dataframe to csv without Index values
df.to_csv('words_frequency.csv',index=False)
# Out:
#      Word  Frequency
# 0     #Ad          1
# 1   Garmi          1
# 2      ka          2
# 3  Mausam          1
# 4      aa          1
# 5    gaya          1
# 6     hai          1
# 7     toh          2
# 8  matlab          1
# 9    naya          1

# %% [markdown]
# 4. Now, find the hashtags that were most popular among these bloggers

# %% [markdown]
# Procedure to complete Task No 4 of Problem 2<br>
# 1. Filter the dictionary for only hashtags<br>
# 2. Create data frame and sort the data into descending order<br>
# 3. Use columns - Words and Frequency for storing the data <br>
# 4. Convert data frame into csv file

# %%
# Filter the hashtag by checking if the words starts with # and store it in hashtags dict
hashtags = {key: value for key, value in word_freq_dict.items() if key.startswith('#')}

hashtags_list = list(hashtags.keys())
hashtags_frequency = list(hashtags.values())

# Create a dictionary with columns
columns = {"Hashtag": hashtags_list, "Frequency": hashtags_frequency}

# Create the pandas dataframe for hashtags
df_hashtags = pd.DataFrame(columns)

# Sort the dataframe in decreasing order based on the 'Frequency' column
df_hashtags_sorted = df_hashtags.sort_values(by='Frequency', ascending=False)

# Save the DataFrame to a CSV file
df_hashtags_sorted.to_csv('hashtags_frequency.csv', index=False)

df_hashtags_sorted
# Out:
#               Hashtag  Frequency
# 154  #punefoodblogger          9
# 6        #dilsefoodie          9
# 7               #food          9
# 155             #pune          8
# 66            #travel          6
# ..                ...        ...
# 70          #himachal          1
# 71              #iias          1
# 72      #outfitsiwore          1
# 74            #ethnic          1
# 197           #paneer          1
#
# [198 rows x 2 columns]

# %% [markdown]
# 5. Plot a Pie Chart of the top 5 hashtags obtained and the number of times they were used by these bloggers in the scraped posts.

# %%
# Select the top 5 rows from the sorted DataFrame
top5_hashtags = df_hashtags_sorted.head(5)

# Plotting the Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(top5_hashtags['Frequency'], labels=top5_hashtags['Hashtag'], autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Hashtags Distribution')
plt.show()

# %% [markdown]
# ## Problem 3

# %% [markdown]
# You need to also calculate average followers : likes ratio for the obtained handles. Followers : Likes ratio is calculated as follows:

# %% [markdown]
# 1. Find out the likes of the top 10 posts of the 5 handles obtained earlier.

# %%
# Function to Get total like of all n no of post of a given Instagram Handle
def Likes_of_post(user_url,No_of_post):
    # Go to insta handle page
    driver.get(user_url)
    sleep(5)
    # Use total likes counter to store the total likes
    Total_Likes = 0

    # Locate and click on the first post
    wait.until(EC.presence_of_element_located((By.CSS_SELECTOR,'div._aabd._aa8k._al3l'))).click()
    sleep(1)
    # Counter to count the no of posts
    count = 1
    
    # Iterate for given no of posts
    while True:
        # Check if no of post are equal to req no
        if No_of_post == count:
            break
        
        # Locate the section tag for like division
        HTML = wait.until(EC.presence_of_element_located((By.XPATH,'//section[@class="_ae5m _ae5n _ae5o"]')))
        # store its content of last span tag in Likes variable 
        Likes = BeautifulSoup(HTML.get_attribute('innerHTML'),'html.parser').find_all('span')[-1]
        # Find the likes in integer ignoring the commas
        Likes = int(Likes.text.replace(',',''))
        # Add the likes to total likes
        Total_Likes += Likes
        # Increment the counter
        count += 1

        # Locate and click on next post button
        wait.until(EC.presence_of_element_located((By.CSS_SELECTOR,"div._aaqg._aaqh"))).click()
        sleep(2)        
    
    driver.back()
    return Total_Likes


# iterate over top 5 user handle and put profile link in function
print("---------------------------------")
print("Total Likes for 10 Posts")
print("---------------------------------")
Total_likes_of_user = {}
# Iterate for top 5 insta handles
for Id in top_5_insta_urls:
    # Get url
    user_url = top_5_insta_urls[Id]

    # Call Likes_of_post function and store it in total likes
    Total_Likes = Likes_of_post(user_url,10)

    # Store the total likes for 10 posts in a dict
    Total_likes_of_user[Id] = Total_Likes

    # Print the result
    print(Id,'--->',Total_Likes)
    print()
# Out:
# ---------------------------------
# Total Likes for 10 Posts
# ---------------------------------
# dilsefoodie ---> 555581
#
# foodtalkindia ---> 581
#
# food_lunatic ---> 12830
#
# food_travel_etc ---> 62997
#
# pune_food_blogger ---> 20386

# %% [markdown]
# 2. Calculate the average likes for a handle.

# %%
# Function to find the avg like per post 
def get_avg_likes(Total_Likes,Number_of_Post):
    # Avg likes = total likes divided by no of posts
    avg_likes = Total_Likes / Number_of_Post
    return avg_likes

# calculating avarge likes for 5 handles for 10 posts and store the result in list
print("---------------------------------")
print("Average Likes")
print("---------------------------------")
average_likes_dict={}
# Iterate for top 5 insta handles
for Id,Total_Likes in Total_likes_of_user.items():
    # CAll get avg function
    avg_likes = get_avg_likes(Total_Likes,10)
    # Store it in dict
    average_likes_dict[Id]=avg_likes
    # print the result
    print(Id,'---->',format(avg_likes,'.0f'))
# Out:
# ---------------------------------
# Average Likes
# ---------------------------------
# dilsefoodie ----> 55558
# foodtalkindia ----> 58
# food_lunatic ----> 1283
# food_travel_etc ----> 6300
# pune_food_blogger ----> 2039

# %% [markdown]
# 3. Divide the average likes obtained from the number of followers of the handle to get the average followers:like ratio of each handle.

# %%
print("---------------------------------")
print("Ratio Avg Followers : Avg Likes")
print("---------------------------------")
avg_followers = {}
for ID in top5_insta_handles:
    avg_followers_count = int(top5_insta_handles[ID]/average_likes_dict[ID])
    avg_followers[ID]=avg_followers_count
    print(ID,'---->',avg_followers_count,':',int(average_likes_dict[ID]))
# Out:
# ---------------------------------
# Ratio Avg Followers : Avg Likes
# ---------------------------------
# dilsefoodie ----> 21 : 55558
# foodtalkindia ----> 5324 : 58
# food_lunatic ----> 173 : 1283
# food_travel_etc ----> 34 : 6299
# pune_food_blogger ----> 105 : 2038

# %% [markdown]
# 4. Create a bar graph to depict the above obtained information.

# %%
#Plotting Bar Graph for average likes of each handle
#for this I will use answer of problem 3.2 
username = list(average_likes_dict.keys())
avg_like = list(average_likes_dict.values())

plt.bar(username,avg_like,color='g',alpha=0.6)
plt.ylabel("Average Likes",size=15)
plt.xlabel("Handle's Name",size=15)
plt.xticks(rotation = 45)
plt.title('Average like for each handle ',fontsize=20, color='red',alpha=0.8)
plt.grid()
plt.show()

# %%
# Plotting Bar Graph for average followers:like ratio of each handle
#For this I will use answer of problem 3.3
username = list(avg_followers.keys())
avg_like = list(avg_followers.values())

plt.bar(username,avg_like,color='Blue',alpha=0.6)
plt.ylabel("Average Followers:Like Ratio",size=12)
plt.xlabel("Handle's Name",size=12)
plt.xticks(rotation = 45)
plt.title('Average Followers:Like Ratio of Each Handle ',fontsize=20, color='Green',alpha=0.8)
plt.grid()
plt.show()

# %%
driver.close()
